# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
banco = pd.read_excel('/content/drive/MyDrive/CEVS/RASCUNHOS/BD_trab1.xlsx') #lê a planilha

# %%
pd.set_option('display.max_rows', None)
banco
# Out:
#       id  grupo  semanasevolucao  diassintomas  tipodeparto  corpele  \
# 0      1      2            32.85           6.0            2        1
# 1      2      1            36.00           4.0            1        1
# 2      3      1            29.00           1.0            1        1
# 3      4      1            27.00           1.0            2        1
# 4      5      1            25.00           1.0            1        1
# 5      6      2            32.85           1.0            2        1
# 6      7      2            31.85          67.0            1        1
# 7      8      2            30.28           7.0            2        1
# 8      9      2            32.43           4.0            1        1
# 9     10      2            32.71           1.0            1        1
# 10    11      2            32.85           1.0            2        1
# 11    12      2            30.71           1.0            2        1
# 12    13      2            27.57           1.0            2        1
# ...

# %% [markdown]
# ### Questão 1

# %%
banco_3v = banco [['grupo', 'tipodeparto', 'fumo']] #seleciona as 3 variáveis escolhidas
banco_3v
# Out:
#      grupo  tipodeparto  fumo
# 0        2            2     1
# 1        1            1     2
# 2        1            1     1
# 3        1            2     1
# 4        1            1     1
# 5        2            2     2
# 6        2            1     1
# 7        2            2     2
# 8        2            1     1
# 9        2            1     2
# 10       2            2     1
# 11       2            2     2
# 12       2            2     1
# 13       2            2     2
# 14       2            2     2
# 15       2            2     1
# 16       2            2     3
# 17       1            2     1
# 18       2            2     2
# 19       2            2     1
# 20       2            1     3
# 21       1            1     2
# 22       1            1     2
# 23       1            1     1
# 24       2            2     2
# 25       2            2     2
# 26       2            2     2
# 27       1            2     3
# 28       2            2     2
# 29       2            2     1
# ...

# %%
quant_grupo = banco_3v['grupo'].value_counts() #conta quantos casos tem de cada tipo de infecção
quant_grupo
# Out:
# 2    76
# 1    45
# Name: grupo, dtype: int64

# %%
porcentagem_grupo = (banco_3v['grupo'].value_counts()/len(banco_3v)*100)
porcentagem_grupo #mostra a porcentagem de cada infecção
# Out:
# Outros                   62.809917
# Pseudomona aeruginosa    37.190083
# Name: grupo, dtype: float64

# %%
banco_3v['tipodeparto'].value_counts() #conta quantas puérperas tiveram cada tipo de parto
# Out:
# 2    89
# 1    32
# Name: tipodeparto, dtype: int64

# %%
porcentagem = (banco_3v['tipodeparto'].value_counts()/len(banco_3v)*100)
porcentagem #mostra a porcentagem de cada tipo de parto
# Out:
# 2    73.553719
# 1    26.446281
# Name: tipodeparto, dtype: float64

# %%
banco_3v['fumo'].value_counts() #conta quantas mulheres tem cada status tabágico
# Out:
# 2    52
# 1    46
# 3    23
# Name: fumo, dtype: int64

# %%
porcentagem = (banco_3v['fumo'].value_counts()/len(banco_3v)*100)
porcentagem #mostra a porcentagem de cada status tabágico
# Out:
# 2    42.975207
# 1    38.016529
# 3    19.008264
# Name: fumo, dtype: float64

# %% [markdown]
# ### Questão 2

# %%
grupo=[["Pseudomona aeruginosa",45, 37], #informações para o gráfico
      ["Outros germes",76,63]
     ]

df=pd.DataFrame(grupo,columns=['Agente infeccioso','Frequência','Porcentagem'])
plot = df.groupby

# %%
df.plot(x="Agente infeccioso", y=['Frequência', 'Porcentagem'], kind="bar", figsize=(5,5), color=['#A58AE3', '#3F3557'], edgecolor='white', linewidth=3) #plotagem do gráfico
width = 0.25
plt.xticks(rotation=0)
plt.show()

# %%
parto=[["Vaginal",32, 26], #informações para o gráfico
      ["Cesariano",89,73]
     ]

df=pd.DataFrame(parto,columns=['Tipo de parto','Frequência','Porcentagem'])
plot = df.groupby

# %%
df.plot(x="Tipo de parto", y=['Frequência', 'Porcentagem'], kind="bar", figsize=(5,5), color=['#FF77A0', '#CC2255'], edgecolor='white', linewidth=3) #plotagem do gráfico
width = 0.25
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Questão 3

# %%
banco_4v = banco [['grupo', 'tipodeparto', 'fumo', 'corpele']]
banco_4v
# Out:
#      grupo  tipodeparto  fumo  corpele
# 0        2            2     1        1
# 1        1            1     2        1
# 2        1            1     1        1
# 3        1            2     1        1
# 4        1            1     1        1
# ..     ...          ...   ...      ...
# 116      2            2     3        2
# 117      2            2     2        1
# 118      1            2     1        1
# 119      2            2     1        2
# 120      1            2     2        1
#
# [121 rows x 4 columns]

# %%
grupo1_parto1 = banco_4v.loc[(banco_4v['grupo']== 1) &
                       (banco_4v['tipodeparto']== 1), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo1_parto1 #para ver o número de mulheres que tiveram infecção urinária por
# Pseudomona aeruginosa e tiveram parto vaginal
# Out:
#      grupo  tipodeparto  fumo  corpele
# 1        1            1     2        1
# 2        1            1     1        1
# 4        1            1     1        1
# 21       1            1     2        2
# 22       1            1     2        2
# 23       1            1     1        1
# 37       1            1     1        1
# 50       1            1     2        1
# 52       1            1     2        2
# 54       1            1     2        2
# 56       1            1     2        2
# 73       1            1     2        1
# 81       1            1     1        1
# 84       1            1     2        1
# 85       1            1     3        1
# 87       1            1     2        1
# 90       1            1     1        2
# 101      1            1     1        1
# 104      1            1     2        1
# 105      1            1     3        1
# 107      1            1     2        1
# 110      1            1     1        2

# %%
grupo1_parto1['grupo'].value_counts() #conta o número de pacientes
# Out:
# 1    22
# Name: grupo, dtype: int64

# %%
grupo1_parto2 = banco_4v.loc[(banco_4v['grupo']== 1) &
                       (banco_4v['tipodeparto']== 2), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo1_parto2 #para ver o número de mulheres que tiveram infecção urinária por
# Pseudomona aeruginosa e tiveram parto cesariano
# Out:
#      grupo  tipodeparto  fumo  corpele
# 3        1            2     1        1
# 17       1            2     1        1
# 27       1            2     3        2
# 31       1            2     1        1
# 41       1            2     2        2
# 46       1            2     1        1
# 61       1            2     3        2
# 62       1            2     2        1
# 70       1            2     2        2
# 71       1            2     2        2
# 72       1            2     3        1
# 75       1            2     2        2
# 80       1            2     3        2
# 82       1            2     2        2
# 83       1            2     2        1
# 95       1            2     1        1
# 98       1            2     1        1
# 100      1            2     2        1
# 102      1            2     2        2
# 103      1            2     2        1
# 115      1            2     1        1
# 118      1            2     1        1
# 120      1            2     2        1

# %%
grupo1_parto2['grupo'].value_counts() #conta o número de pacientes
# Out:
# 1    23
# Name: grupo, dtype: int64

# %%
grupo2_parto1 = banco_4v.loc[(banco_4v['grupo']== 2) &
                       (banco_4v['tipodeparto']== 1), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo2_parto1 #para ver o número de mulheres que tiveram infecção urinária por
# outros germes e tiveram parto vaginal
# Out:
#     grupo  tipodeparto  fumo  corpele
# 6       2            1     1        1
# 8       2            1     1        1
# 9       2            1     2        1
# 20      2            1     3        1
# 32      2            1     1        1
# 36      2            1     1        1
# 55      2            1     1        1
# 59      2            1     3        1
# 68      2            1     3        2
# 69      2            1     1        1

# %%
grupo2_parto1['grupo'].value_counts() #conta o número de pacientes
# Out:
# 2    10
# Name: grupo, dtype: int64

# %%
grupo2_parto2 = banco_4v.loc[(banco_4v['grupo']== 2) &
                       (banco_4v['tipodeparto']== 2), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo2_parto2 #para ver o número de mulheres que tiveram infecção urinária por
# outros germes e tiveram parto cesariano
# Out:
#      grupo  tipodeparto  fumo  corpele
# 0        2            2     1        1
# 5        2            2     2        1
# 7        2            2     2        1
# 10       2            2     1        1
# 11       2            2     2        1
# ..     ...          ...   ...      ...
# 113      2            2     3        2
# 114      2            2     2        2
# 116      2            2     3        2
# 117      2            2     2        1
# 119      2            2     1        2
#
# [66 rows x 4 columns]

# %%
grupo2_parto2['grupo'].value_counts() #conta o número de pacientes
# Out:
# 2    66
# Name: grupo, dtype: int64

# %% [markdown]
# Resultados da relação grupo/parto:
# - das mulheres infectadas por Pseudomona aeruginosa, 22 tiveram parto vaginal e 23 tiveram parto cesariano
# - das mulheres infectadas por outros germes, 10 tiveram parto vaginal e 66 tiveram parto cesariano
# - baseado nesses resultados, podemos interpretar que mulheres que tiveram parto cesariano tiveram maior probabilidade de serem infectadas por outros germes, que não fossem Pseudomona aeruginosa.

# %%
grupo1_fumo1 = banco_4v.loc[(banco_4v['grupo']== 1) &
                       (banco_4v['fumo']== 1), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo1_fumo1 #para ver o número de mulheres que tiveram infecção urinária por
# Pseudomona aeruginosa e são fumantes
# Out:
#      grupo  tipodeparto  fumo  corpele
# 2        1            1     1        1
# 3        1            2     1        1
# 4        1            1     1        1
# 17       1            2     1        1
# 23       1            1     1        1
# 31       1            2     1        1
# 37       1            1     1        1
# 46       1            2     1        1
# 81       1            1     1        1
# 90       1            1     1        2
# 95       1            2     1        1
# 98       1            2     1        1
# 101      1            1     1        1
# 110      1            1     1        2
# 115      1            2     1        1
# 118      1            2     1        1

# %%
grupo1_fumo1['grupo'].value_counts() #conta o número de pacientes
# Out:
# 1    16
# Name: grupo, dtype: int64

# %%
grupo1_fumo2 = banco_4v.loc[(banco_4v['grupo']== 1) &
                       (banco_4v['fumo']== 2), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo1_fumo2 #para ver o número de mulheres que tiveram infecção urinária por
# Pseudomona aeruginosa e não são fumantes
# Out:
#      grupo  tipodeparto  fumo  corpele
# 1        1            1     2        1
# 21       1            1     2        2
# 22       1            1     2        2
# 41       1            2     2        2
# 50       1            1     2        1
# 52       1            1     2        2
# 54       1            1     2        2
# 56       1            1     2        2
# 62       1            2     2        1
# 70       1            2     2        2
# 71       1            2     2        2
# 73       1            1     2        1
# 75       1            2     2        2
# 82       1            2     2        2
# 83       1            2     2        1
# 84       1            1     2        1
# 87       1            1     2        1
# 100      1            2     2        1
# 102      1            2     2        2
# 103      1            2     2        1
# 104      1            1     2        1
# 107      1            1     2        1
# 120      1            2     2        1

# %%
grupo1_fumo2['grupo'].value_counts() #conta o número de pacientes
# Out:
# 1    23
# Name: grupo, dtype: int64

# %%
grupo1_fumo3 = banco_4v.loc[(banco_4v['grupo']== 1) &
                       (banco_4v['fumo']== 3), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo1_fumo3 #para ver o número de mulheres que tiveram infecção urinária por
# Pseudomona aeruginosa e são ex-fumantes
# Out:
#      grupo  tipodeparto  fumo  corpele
# 27       1            2     3        2
# 61       1            2     3        2
# 72       1            2     3        1
# 80       1            2     3        2
# 85       1            1     3        1
# 105      1            1     3        1

# %%
grupo1_fumo3['grupo'].value_counts() #conta o número de pacientes
# Out:
# 1    6
# Name: grupo, dtype: int64

# %%
grupo2_fumo1 = banco_4v.loc[(banco_4v['grupo']== 2) &
                       (banco_4v['fumo']== 1), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo2_fumo1 #para ver o número de mulheres que tiveram infecção urinária por
# outros germes e são fumantes
# Out:
#      grupo  tipodeparto  fumo  corpele
# 0        2            2     1        1
# 6        2            1     1        1
# 8        2            1     1        1
# 10       2            2     1        1
# 12       2            2     1        1
# 15       2            2     1        1
# 19       2            2     1        1
# 29       2            2     1        1
# 32       2            1     1        1
# 35       2            2     1        2
# 36       2            1     1        1
# 39       2            2     1        1
# 42       2            2     1        1
# 44       2            2     1        1
# 47       2            2     1        2
# 48       2            2     1        2
# 51       2            2     1        2
# 53       2            2     1        2
# 55       2            1     1        1
# 58       2            2     1        1
# 60       2            2     1        1
# 64       2            2     1        2
# 67       2            2     1        1
# ...

# %%
grupo2_fumo1['grupo'].value_counts() #conta o número de pacientes
# Out:
# 2    30
# Name: grupo, dtype: int64

# %%
grupo2_fumo2 = banco_4v.loc[(banco_4v['grupo']== 2) &
                       (banco_4v['fumo']== 2), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo2_fumo2 #para ver o número de mulheres que tiveram infecção urinária por
# outros germes e não são fumantes
# Out:
#      grupo  tipodeparto  fumo  corpele
# 5        2            2     2        1
# 7        2            2     2        1
# 9        2            1     2        1
# 11       2            2     2        1
# 13       2            2     2        1
# 14       2            2     2        1
# 18       2            2     2        1
# 24       2            2     2        1
# 25       2            2     2        2
# 26       2            2     2        1
# 28       2            2     2        1
# 30       2            2     2        1
# 38       2            2     2        1
# 43       2            2     2        1
# 45       2            2     2        2
# 57       2            2     2        1
# 63       2            2     2        1
# 65       2            2     2        1
# 66       2            2     2        1
# 77       2            2     2        2
# 78       2            2     2        2
# 86       2            2     2        1
# 89       2            2     2        2
# ...

# %%
grupo2_fumo2['grupo'].value_counts() #conta o número de pacientes
# Out:
# 2    29
# Name: grupo, dtype: int64

# %%
grupo2_fumo3 = banco_4v.loc[(banco_4v['grupo']== 2) &
                       (banco_4v['fumo']== 3), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo2_fumo3 #para ver o número de mulheres que tiveram infecção urinária por
# outros germes e são ex-fumantes
# Out:
#      grupo  tipodeparto  fumo  corpele
# 16       2            2     3        2
# 20       2            1     3        1
# 33       2            2     3        2
# 34       2            2     3        2
# 40       2            2     3        1
# 49       2            2     3        2
# 59       2            1     3        1
# 68       2            1     3        2
# 74       2            2     3        1
# 91       2            2     3        2
# 92       2            2     3        2
# 93       2            2     3        2
# 96       2            2     3        2
# 111      2            2     3        2
# 112      2            2     3        2
# 113      2            2     3        2
# 116      2            2     3        2

# %%
grupo2_fumo3['grupo'].value_counts() #conta o número de pacientes
# Out:
# 2    17
# Name: grupo, dtype: int64

# %% [markdown]
# Resultado da relação grupo/status tabágico da mãe:
# - das mulheres infectadas por Pseudomona aeruginosa, 16 delas são fumantes, 23 delas não são fumantes e 6 delas são ex-fumantes;
# - das mulheres infectadas por outros germes, 30 delas são fumantes, 29 delas não são fumantes e 17 delas são ex-fumantes.
# - visto que não há grande disparidade nesses resultados, podemos interpretar que o status tabágico da mãe não tem relação com a infecção contraída.

# %%
grupo1_corpele1 = banco_4v.loc[(banco_4v['grupo']== 1) &
                       (banco_4v['corpele']== 1), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo1_corpele1 #para ver o número de mulheres que tiveram infecção urinária por
# Pseudomona aeruginosa e têm cor de pele branca
# Out:
#      grupo  tipodeparto  fumo  corpele
# 1        1            1     2        1
# 2        1            1     1        1
# 3        1            2     1        1
# 4        1            1     1        1
# 17       1            2     1        1
# 23       1            1     1        1
# 31       1            2     1        1
# 37       1            1     1        1
# 46       1            2     1        1
# 50       1            1     2        1
# 62       1            2     2        1
# 72       1            2     3        1
# 73       1            1     2        1
# 81       1            1     1        1
# 83       1            2     2        1
# 84       1            1     2        1
# 85       1            1     3        1
# 87       1            1     2        1
# 95       1            2     1        1
# 98       1            2     1        1
# 100      1            2     2        1
# 101      1            1     1        1
# 103      1            2     2        1
# ...

# %%
grupo1_corpele1['grupo'].value_counts() #conta o número de pacientes
# Out:
# 1    29
# Name: grupo, dtype: int64

# %%
grupo1_corpele2 = banco_4v.loc[(banco_4v['grupo']== 1) &
                       (banco_4v['corpele']== 2), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo1_corpele2 #para ver o número de mulheres que tiveram infecção urinária por
# Pseudomona aeruginosa e têm cor de pele negra ou parda
# Out:
#      grupo  tipodeparto  fumo  corpele
# 21       1            1     2        2
# 22       1            1     2        2
# 27       1            2     3        2
# 41       1            2     2        2
# 52       1            1     2        2
# 54       1            1     2        2
# 56       1            1     2        2
# 61       1            2     3        2
# 70       1            2     2        2
# 71       1            2     2        2
# 75       1            2     2        2
# 80       1            2     3        2
# 82       1            2     2        2
# 90       1            1     1        2
# 102      1            2     2        2
# 110      1            1     1        2

# %%
grupo1_corpele2['grupo'].value_counts() #conta o número de pacientes
# Out:
# 1    16
# Name: grupo, dtype: int64

# %%
grupo2_corpele1 = banco_4v.loc[(banco_4v['grupo']== 2) &
                       (banco_4v['corpele']== 1), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo2_corpele1 #para ver o número de mulheres que tiveram infecção urinária por
# outros germes e têm cor de pele branca
# Out:
#      grupo  tipodeparto  fumo  corpele
# 0        2            2     1        1
# 5        2            2     2        1
# 6        2            1     1        1
# 7        2            2     2        1
# 8        2            1     1        1
# 9        2            1     2        1
# 10       2            2     1        1
# 11       2            2     2        1
# 12       2            2     1        1
# 13       2            2     2        1
# 14       2            2     2        1
# 15       2            2     1        1
# 18       2            2     2        1
# 19       2            2     1        1
# 20       2            1     3        1
# 24       2            2     2        1
# 26       2            2     2        1
# 28       2            2     2        1
# 29       2            2     1        1
# 30       2            2     2        1
# 32       2            1     1        1
# 36       2            1     1        1
# 38       2            2     2        1
# ...

# %%
grupo2_corpele1['grupo'].value_counts() #conta o número de pacientes
# Out:
# 2    46
# Name: grupo, dtype: int64

# %%
grupo2_corpele2 = banco_4v.loc[(banco_4v['grupo']== 2) &
                       (banco_4v['corpele']== 2), ['grupo', 'tipodeparto', 'fumo', 'corpele']]
grupo2_corpele1 #para ver o número de mulheres que tiveram infecção urinária por
# outros germes e têm cor de pele negra ou parda
# Out:
#      grupo  tipodeparto  fumo  corpele
# 0        2            2     1        1
# 5        2            2     2        1
# 6        2            1     1        1
# 7        2            2     2        1
# 8        2            1     1        1
# 9        2            1     2        1
# 10       2            2     1        1
# 11       2            2     2        1
# 12       2            2     1        1
# 13       2            2     2        1
# 14       2            2     2        1
# 15       2            2     1        1
# 18       2            2     2        1
# 19       2            2     1        1
# 20       2            1     3        1
# 24       2            2     2        1
# 26       2            2     2        1
# 28       2            2     2        1
# 29       2            2     1        1
# 30       2            2     2        1
# 32       2            1     1        1
# 36       2            1     1        1
# 38       2            2     2        1
# ...

# %%
grupo2_corpele2['grupo'].value_counts() #conta o número de pacientes
# Out:
# 2    30
# Name: grupo, dtype: int64

# %% [markdown]
# Resultado da relação grupo/cor de pele:
#
# - das mulheres infectadas por Pseudomona aeruginosa, 29 delas são brancas e 16 delas são negras ou pardas;
# - das mulheres infectadas por outros germes, 46 delas são brancas e 30 delas são negras ou pardas;
# - visto que não há grande disparidade nesses resultados, podemos interpretar que a cor de pele da mãe não tem relação com a infecção contraída.
